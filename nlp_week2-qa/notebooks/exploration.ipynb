# %% [markdown]
# # Week 2 — Exploration Scratch Pad
#
# This notebook is for exploration only. Production code lives in `src/` and `experiments/`.

# %%
import sys
sys.path.insert(0, '..')

from src.dataset import load_processed

df = load_processed()
df.head()
